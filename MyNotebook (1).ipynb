# %% [markdown]
# # Introduction
# This notebook contains my work for Exercise 3.
# I will be using this notebook to explore basic Jupyter Notebook features.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Java
# - Julia

# %% [markdown]
# ## Data Science Libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 1. Pandas
# 1. Matplotlib
# 1. Scikit-learn
# 1. TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Visual Studio Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This code multiplies and adds numbers
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# ### This will convert 200 minutes to hours by dividing by 60.

# %%
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# Objectives:
# - List popular Data Science languages
# - Identify commonly used libraries
# - Create simple arithmetic expressions using Python
# - Convert minutes to hours using Python code

# %% [markdown]
# ## Author
# Michael Abundabar
